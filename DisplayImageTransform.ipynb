# %%
from preprocessingdata import default_loader, myImageFloder, testmyImageFolder


imgLoader = testmyImageFolder()
print imgLoader

for i, data in enumerate(imgLoader, 0):
    print i
    print type(data)
    print len(data)
    image = data[0][0]
    label = data[1][0]
    
    print type(data[0])
    print data[0].size()
    
    print type(data[1])
    print data[1].size()
    
    
    
    if i == 0:
        break
# Out:
# ...
# 0
# <type 'list'>
# 2
# <class 'torch.FloatTensor'>
# torch.Size([64, 3, 224, 224])
# <class 'torch.FloatTensor'>
# torch.Size([64, 1])

# %%
print image.size()
print label.size()
# Out:
# torch.Size([3, 224, 224])
# torch.Size([1])

# %%
image_np = image.numpy()
label_np = label.numpy()
print image_np.shape
print label_np.shape
# Out:
# (3, 224, 224)
# (1,)

# %%
import matplotlib.pyplot as plt
from PIL import Image

plt.figure()
image_np_tran = image_np.transpose((1,2,0))
print image_np_tran.shape
plt.imshow(image_np_tran)
plt.axis()
plt.show()
# Out:
# (224, 224, 3)
